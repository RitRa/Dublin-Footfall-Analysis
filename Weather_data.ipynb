# %% [markdown]
# Finding sources for weather in Dublin in 2015. Data taken from the library python meteostat https://meteostat.net/en/
# https://dev.meteostat.net/formats.html#meteorological-parameters

# %%
# !pip install meteostat

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2015, 1, 1)
end = datetime(2015, 12, 31)

# Create Point for Dublin, Ireland
location = Point(53.3331, -6.2489)

# Get daily data for 2015
data = Daily(location, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2015, 1, 1)
end = datetime(2015, 12, 31)


# Create Point for Dublin, Ireland
location = Point(53.3331, -6.2489)


# Get daily data for 2015
data = Daily(location, start, end)
data = data.fetch()
data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2015-01-01  11.4   8.9  14.1   4.6   NaN  214.0  39.9   NaN  1013.3   NaN
# 2015-01-02   5.4   3.2   6.8   8.4   NaN  241.0  31.8   NaN  1026.8   NaN
# 2015-01-03   3.1   3.5   5.8   1.2   NaN  315.0  12.6   NaN  1023.8   NaN
# 2015-01-04   2.2  -2.4   9.8   0.0   NaN  186.0   8.0   NaN  1031.4   NaN
# 2015-01-05   8.5  -1.6  12.0   0.8   NaN  196.0  14.9   NaN  1021.2   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2015-12-27   5.7  -0.8  13.0   0.0   NaN  170.0  14.9   NaN  1013.5   NaN
# 2015-12-28  11.5  -0.8  13.6   4.9   NaN  154.0  31.5   NaN  1002.0   NaN
# 2015-12-29   9.3   6.6  14.2  14.5   NaN  171.0  29.4   NaN  1003.3   NaN
# 2015-12-30   9.2   6.6  10.9   5.8   NaN  183.0  32.1   NaN   993.6   NaN
# 2015-12-31   4.3   3.1   7.1   0.7   NaN  218.0  26.6   NaN  1002.8   NaN
#
# [365 rows x 10 columns]

# %%
import csv
with open("data/weather.csv", "w") as text_file:
    text_file.write(data.to_csv(index=True))
